# %%
import pandas as pd

# load and clean playerStats and teamStats 
player_data = pd.read_csv("playerStats.csv")
team_data = pd.read_csv("teamStats.csv")

# clean dataframe from lable rows
filtered_player_df = player_data[player_data['FGM'] != 'FGM']


# convert columns to correct types for numeric opperations
dfn = filtered_player_df.convert_dtypes()

dfn[["SEASON_ID", "Player_ID", "Game_ID", "MIN", "FGM", "FGA", "FG_PCT", "FG3M", "FG3A", "FG3_PCT", "FTM", "FTA", "FT_PCT", "OREB", "DREB", "REB", "AST", "STL", "BLK", "TOV", "PF", "PTS", "PLUS_MINUS"]] = dfn[["SEASON_ID", "Player_ID", "Game_ID", "MIN", "FGM", "FGA", "FG_PCT", "FG3M", "FG3A", "FG3_PCT", "FTM", "FTA", "FT_PCT", "OREB", "DREB", "REB", "AST", "STL", "BLK", "TOV", "PF", "PTS", "PLUS_MINUS"]].apply(pd.to_numeric)
player_data = dfn

# encode win/loss
# win == 1
# loss == 0
player_data['WL'] = player_data['WL'].map({'W': 1, 'L': 0})

# %%
# player_data holds player stats in correct type format
# now we can explore how these numbers relate and generate hypotheses
GAFFORD_ID = 1629655
WASHINGTON_ID = 1629023
LUKA_ID = 1629029
KYRIE_ID = 202681
WILLIAMS_ID = 1629684
LIVELY_ID = 1641726
POWELL_ID = 203939
JONESJR_ID = 1627884
KLEBER_ID = 1628467
GREEN_ID = 1630182
THJ_ID = 203501
#print(player_data.corr())

kyrie_df = player_data[player_data['Player_ID'] == THJ_ID]
print(kyrie_df.corr())
# Out:
#               Unnamed: 0  SEASON_ID  Player_ID   Game_ID        WL       MIN  \
# Unnamed: 0  1.000000e+00        NaN        NaN -0.877673 -0.493829  0.416733
# SEASON_ID            NaN        NaN        NaN       NaN       NaN       NaN
# Player_ID            NaN        NaN        NaN       NaN       NaN       NaN
# Game_ID    -8.776725e-01        NaN        NaN  1.000000  0.367707 -0.303660
# WL         -4.938292e-01        NaN        NaN  0.367707  1.000000 -0.634346
# MIN         4.167331e-01        NaN        NaN -0.303660 -0.634346  1.000000
# FGM         3.110437e-01        NaN        NaN -0.298520  0.012578  0.650501
# FGA         4.046494e-01        NaN        NaN -0.378209 -0.074397  0.673078
# FG_PCT      2.218105e-01        NaN        NaN -0.425194 -0.244289  0.618906
# FG3M        2.396169e-01        NaN        NaN -0.283455 -0.150188  0.784585
# FG3A        3.742727e-01        NaN        NaN -0.350252 -0.335125  0.798321
# FG3_PCT     3.733226e-01        NaN        NaN -0.412059 -0.315205  0.775705
# FTM         3.418817e-01        NaN        NaN -0.207288  0.047619  0.391802
# FTA         1.574592e-01        NaN        NaN  0.014020  0.065795  0.180451
# FT_PCT      4.586825e-01        NaN        NaN -0.314409 -0.106479  0.400501
# OREB       -2.611165e-01        NaN        NaN -0.063106 -0.218218  0.128247
# DREB        2.785397e-01        NaN        NaN  0.022563 -0.349168  0.504017
# REB         1.992469e-01        NaN        NaN  0.001365 -0.441899  0.572105
# AST         3.553345e-01        NaN        NaN -0.369721  0.089087  0.418854
# STL         1.183502e-17        NaN        NaN  0.032543  0.089087  0.104713
# BLK        -2.901294e-01        NaN        NaN -0.034690  0.218218 -0.398992
# TOV        -1.740777e-01        NaN        NaN -0.068642 -0.218218  0.384742
# FG3M        0.231843  0.282785  0.655610  1.873172e-01 -0.305888  0.401478
# FG3A        0.077599  0.081129  0.501570  1.020900e-17 -0.307148  0.307148
# FG3_PCT     0.308404  0.343003  0.452676  6.073791e-03 -0.325705  0.422701
# FTM         0.202150  0.134491  0.311805 -3.563483e-01 -0.145479 -0.218218
# FTA         0.025392 -0.079640  0.123091 -4.923660e-01 -0.201008 -0.301511
# FT_PCT      0.287650  0.214808  0.199205 -3.984095e-01 -0.162650 -0.243975
# OREB       -0.294753  0.044023  0.102062  1.020621e-01  0.666667  0.375000
# DREB        1.000000  0.941671  0.034381  3.781878e-01 -0.477219 -0.084215
# REB         0.941671  1.000000  0.071889  4.313311e-01 -0.264135  0.044023
# AST         0.034381  0.071889  1.000000  5.833333e-01 -0.272166  0.102062
# STL         0.378188  0.431331  0.583333  1.000000e+00 -0.272166  0.102062
# BLK        -0.477219 -0.264135 -0.272166 -2.721655e-01  1.000000 -0.166667
# TOV        -0.084215  0.044023  0.102062  1.020621e-01 -0.166667  1.000000
# PF          0.078014  0.348493  0.378188  2.062842e-01  0.084215  0.547399
# PTS         0.183229  0.170277  0.518137 -1.809367e-01 -0.174595  0.090655
# PLUS_MINUS  0.191588  0.083294  0.262075  7.816278e-02 -0.165180  0.005631
#
#                   PF       PTS  PLUS_MINUS
# Unnamed: 0  0.043980  0.322634   -0.066657
# SEASON_ID        NaN       NaN         NaN
# Player_ID        NaN       NaN         NaN
# Game_ID    -0.186287 -0.296728    0.092817
# WL         -0.532941 -0.008792    0.619324
# MIN         0.604821  0.664850   -0.075107
# FGM         0.247558  0.996285    0.410261
# FGA         0.075694  0.887879    0.187795
# FG_PCT      0.586305  0.764773    0.035986
# FG3M        0.521648  0.836530    0.152441
# FG3A        0.284531  0.668268   -0.138367
# FG3_PCT     0.529509  0.801591    0.106980
# FTM         0.110264  0.848452    0.557883
# FTA         0.025392  0.656005    0.363341
# FT_PCT      0.123278  0.786403    0.417653
# OREB        0.757937 -0.060437   -0.332238
# DREB        0.078014  0.183229    0.191588
# REB         0.348493  0.170277    0.083294
# AST         0.378188  0.518137    0.262075
# STL         0.206284 -0.180937    0.078163
# BLK         0.084215 -0.174595   -0.165180
# TOV         0.547399  0.090655    0.005631
# PF          1.000000  0.285023   -0.225733
# PTS         0.285023  1.000000    0.416561
# PLUS_MINUS -0.225733  0.416561    1.000000
#
# [25 rows x 25 columns]
# /var/folders/35/l9gpx2xs2m3cbhhnbkchpc7m0000gn/T/ipykernel_34400/517279322.py:17: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(kyrie_df.corr())

# %%
numgames = 4 + 6 + 4 + 5 + 7 + 5 + 6 + 5 + 7 + 6 + 6 + 7 + 4 + 5
numgames
# Out:
# 77

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# log regression
team_data = pd.read_csv("teamStats.csv")


team_data['WL'] = team_data['WL'].map({'W': 1, 'L': 0})

feature_cols = ['FG_PCT', 'STL', 'BLK', 'PTS','AST','DREB']
X = team_data[feature_cols] # Features
y = team_data.WL 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=16)

# instantiate the model (using the default parameters)
logreg = LogisticRegression(random_state=16)

# fit the model with data
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# (17, 28)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# log regression
playoff_data = pd.read_csv("bigStats/playoffs.csv")
playoff_data = playoff_data[playoff_data['FGM'] != 'FGM']
print(playoff_data)

playoff_data['WL'] = playoff_data['WL'].map({'W': 1, 'L': 0})
playoff_data[["SEASON_ID", "Game_ID", "MIN", "FGM", "FGA", "FG_PCT", "FG3M", "FG3A", "FG3_PCT", "FTM", "FTA", "FT_PCT", "OREB", "DREB", "REB", "AST", "STL", "BLK", "TOV", "PF", "PTS", "PLUS_MINUS"]] = dfn[["SEASON_ID", "Game_ID", "MIN", "FGM", "FGA", "FG_PCT", "FG3M", "FG3A", "FG3_PCT", "FTM", "FTA", "FT_PCT", "OREB", "DREB", "REB", "AST", "STL", "BLK", "TOV", "PF", "PTS", "PLUS_MINUS"]].apply(pd.to_numeric)
z
# print(null_rows)
# print(playoff_data.dtypes)

# feature_cols = ['FG_PCT', 'STL', 'BLK', 'PTS','AST','DREB']
# X = playoff_data[feature_cols] # Features
# y = playoff_data.WL 

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=16)

# # instantiate the model (using the default parameters)
# logreg = LogisticRegression(random_state=16)

# # fit the model with data
# logreg.fit(X_train, y_train)

# y_pred = logreg.predict(X_test)

# cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
# cnf_matrix
# Out:
#      Unnamed: 0 SEASON_ID     TEAM_ID TEAM_ABBREVIATION  \
# 0           0.0     42019  1610612761               TOR
# 1           1.0     42019  1610612743               DEN
# 2           2.0     42019  1610612751               BKN
# 3           3.0     42019  1610612742               DAL
# 4           4.0     42019  1610612762               UTA
# ..          ...       ...         ...               ...
# 831       149.0     42023  1610612738               BOS
# 832       150.0     42023  1610612750               MIN
# 833       151.0     42023  1610612742               DAL
# 834       152.0     42023  1610612742               DAL
# 835       153.0     42023  1610612750               MIN
#
#                   TEAM_NAME     GAME_ID   GAME_DATE      MATCHUP WL  MIN  ...  \
# 0           Toronto Raptors  0041900111  2020-08-17  TOR vs. BKN  W  240  ...
# 1            Denver Nuggets  0041900161  2020-08-17  DEN vs. UTA  W  265  ...
# 2             Brooklyn Nets  0041900111  2020-08-17    BKN @ TOR  L  240  ...
# 3          Dallas Mavericks  0041900151  2020-08-17    DAL @ LAC  L  240  ...
# 4                 Utah Jazz  0041900161  2020-08-17    UTA @ DEN  L  265  ...
# ..                      ...         ...         ...          ... ..  ...  ...
# 831          Boston Celtics  0042300304  2024-05-27    BOS @ IND  W  240  ...
# 832  Minnesota Timberwolves  0042300314  2024-05-28    MIN @ DAL  W  240  ...
# 833        Dallas Mavericks  0042300314  2024-05-28  DAL vs. MIN  L  240  ...
# 834        Dallas Mavericks  0042300315  2024-05-30    DAL @ MIN  W  240  ...
# 835  Minnesota Timberwolves  0042300315  2024-05-30  MIN vs. DAL  L  240  ...
#
#     DREB REB AST STL BLK TOV  PF  PTS PLUS_MINUS VIDEO_AVAILABLE
# 0     38  47  26   4   6  12  22  134         24               1
# 1     33  41  23  10   6  12  22  135         10               1
# 2     36  45  33   4   2  14  29  110        -24               1
# 3     36  41  18   9   2  21  21  110         -8               1
# 4     36  52  18   6   4  16  22  125        -10               1
# ..   ...  ..  ..  ..  ..  ..  ..  ...        ...             ...
# 831   32  44  22  10   6  13  18  105          3               1
# 832   34  40  23   9   4  15  23  105          5               1
# 833   28  38  23   6   4  14  22  100         -5               1
# 834   36  45  19   7   5  13  20  124         21               1
# 835   28  41  17   8   5  14  17  103        -21               1
#
# [832 rows x 30 columns]
#      Unnamed: 0  SEASON_ID     TEAM_ID TEAM_ABBREVIATION  \
# 0           0.0    42023.0  1610612761               TOR
# 1           1.0    42023.0  1610612743               DEN
# 2           2.0    42023.0  1610612751               BKN
# 3           3.0    42023.0  1610612742               DAL
# 4           4.0    42023.0  1610612762               UTA
# ..          ...        ...         ...               ...
# 831       149.0        NaN  1610612738               BOS
# 832       150.0        NaN  1610612750               MIN
# 833       151.0        NaN  1610612742               DAL
# 834       152.0        NaN  1610612742               DAL
# 835       153.0        NaN  1610612750               MIN
#
#                   TEAM_NAME     GAME_ID   GAME_DATE      MATCHUP  WL   MIN  \
# 0           Toronto Raptors  0041900111  2020-08-17  TOR vs. BKN   1  20.0
# 1            Denver Nuggets  0041900161  2020-08-17  DEN vs. UTA   1  31.0
# 2             Brooklyn Nets  0041900111  2020-08-17    BKN @ TOR   0  29.0
# 3          Dallas Mavericks  0041900151  2020-08-17    DAL @ LAC   0  21.0
# 4                 Utah Jazz  0041900161  2020-08-17    UTA @ DEN   0  21.0
# ..                      ...         ...         ...          ...  ..   ...
# 831          Boston Celtics  0042300304  2024-05-27    BOS @ IND   1   NaN
# 832  Minnesota Timberwolves  0042300314  2024-05-28    MIN @ DAL   1   NaN
# 833        Dallas Mavericks  0042300314  2024-05-28  DAL vs. MIN   0   NaN
# 834        Dallas Mavericks  0042300315  2024-05-30    DAL @ MIN   1   NaN
# 835  Minnesota Timberwolves  0042300315  2024-05-30  MIN vs. DAL   0   NaN
#
#      ...  REB  AST  STL  BLK  TOV   PF   PTS  PLUS_MINUS  VIDEO_AVAILABLE  \
# 0    ...  9.0  0.0  0.0  1.0  2.0  5.0  11.0        26.0                1
# 1    ...  8.0  1.0  1.0  3.0  0.0  3.0  12.0        -1.0                1
# 2    ...  3.0  1.0  0.0  3.0  3.0  4.0   5.0        10.0                1
# 3    ...  5.0  0.0  0.0  5.0  0.0  2.0  16.0        -3.0                1
# 4    ...  9.0  0.0  0.0  1.0  2.0  2.0  10.0       -15.0                1
# ..   ...  ...  ...  ...  ...  ...  ...   ...         ...              ...
# 831  ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN         NaN                1
# 832  ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN         NaN                1
# 833  ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN         NaN                1
# 834  ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN         NaN                1
# 835  ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN         NaN                1
#
#         Game_ID
# 0    42300315.0
# 1    42300314.0
# 2    42300313.0
# 3    42300312.0
# 4    42300311.0
# ..          ...
# 831         NaN
# 832         NaN
# 833         NaN
# 834         NaN
# 835         NaN
#
# [832 rows x 31 columns]
